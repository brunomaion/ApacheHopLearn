# %%
import pandas as pd

# Assuming you want to read a CSV file into a pandas DataFrame
df = pd.read_csv('Bakery Sales.csv')
display(df)
df.info()
# Out:
#               datetime day of week    total place  angbutter  plain bread  \
# 0     2019-07-11 15:35        Thur  23800.0   NaN        1.0          NaN
# 1     2019-07-11 16:10        Thur  15800.0   NaN        1.0          NaN
# 2     2019-07-12 11:49         Fri  58000.0   NaN        NaN          NaN
# 3     2019-07-13 13:19         Sat  14800.0   NaN        1.0          1.0
# 4     2019-07-13 13:22         Sat  15600.0   NaN        2.0          NaN
# ...                ...         ...      ...   ...        ...          ...
# 2649               NaN         NaN      NaN   NaN        NaN          NaN
# 2650               NaN         NaN      NaN   NaN        NaN          NaN
# 2651               NaN         NaN      NaN   NaN        NaN          NaN
# 2652               NaN         NaN      NaN   NaN        NaN          NaN
# 2653  2020-06-18 14:52         NaN      NaN   NaN        NaN          NaN
#
#       jam  americano  croissant  caffe latte  ...  gateau chocolat  pandoro  \
# ...

# %%
dfProdutos = df


dfProdutos = dfProdutos.drop(columns=['total', 'place'])

dfProdutos_melt = dfProdutos.melt(id_vars=['datetime', 'day of week'], var_name='product', value_name='quantity')

dfProdutos_melt = dfProdutos_melt.dropna(subset=['quantity']).sort_values(by=['datetime'])
display(dfProdutos_melt)

dfProdutos_melt.to_csv('vendas.csv', index=False)
# Out:
#                datetime day of week             product  quantity
# 0      2019-07-11 15:35        Thur           angbutter       1.0
# 15924  2019-07-11 15:35        Thur  tiramisu croissant       3.0
# 50426  2019-07-11 15:35        Thur        vanila latte       1.0
# 7962   2019-07-11 15:35        Thur           americano       1.0
# 15925  2019-07-11 16:10        Thur  tiramisu croissant       1.0
# ...                 ...         ...                 ...       ...
# 18342  2020-05-02 13:45         Sat  tiramisu croissant       1.0
# 18343  2020-05-02 14:45         Sat  tiramisu croissant       1.0
# 47537  2020-05-02 14:45         Sat        orange pound       1.0
# 23651  2020-05-02 14:45         Sat    pain au chocolat       1.0
# 2419   2020-05-02 14:45         Sat           angbutter       2.0
#
# [8285 rows x 4 columns]
